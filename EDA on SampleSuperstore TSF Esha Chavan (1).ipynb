# %% [markdown]
# # TOPIC: EXPLORATORY DATA ANALYSIS- RETAIL
#
# # DATASET : SampleSuperstore (https://bit.ly/3i4rbWl)
#
# # AUTHOR : ESHA GANESH CHAVAN
#
# # LEVEL: BEGINNER

# %% [markdown]
# # Importing Required Libraries:

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Loading the Dataset:

# %%
d=pd.read_csv("C:\\Users\\Esha\\Desktop\\dataset\\SampleSuperstore.csv",encoding='latin1')
df=pd.DataFrame(d)
df.head(10)
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5  Standard Class   Consumer  United States      Los Angeles  California
# 6  Standard Class   Consumer  United States      Los Angeles  California
# 7  Standard Class   Consumer  United States      Los Angeles  California
# 8  Standard Class   Consumer  United States      Los Angeles  California
# 9  Standard Class   Consumer  United States      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# ...

# %% [markdown]
# # Analysing the Dataset

# %% [markdown]
# # This dataset consists of 9994 records and 13 attributes

# %%
df.shape
# Out:
# (9994, 13)

# %% [markdown]
# # Out of these 13 columns , 5 are numerical and 8 are categorical columns.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [markdown]
# # Highest Profit gained is 8399
# # Highest Discount 0.80

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
#Number of unique values present in each column
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %% [markdown]
# # Sales and profit have moderate positive correlation i.e. as sales increases profit moderately increases.
# # Discount and Profit have weak negative correlation i.e. as discount increases profit decreases slightly.

# %%
corr=df.corr()
sns.heatmap(corr,annot=True,cmap='Reds')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Handling Null and Duplicate Values:

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# # No Null Values present in the Dataset

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.duplicated().sum()
# Out:
# 17

# %% [markdown]
# # 17 duplicate records are present in this dataset.

# %%
df.duplicated(subset=['Sales'])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9989     True
# 9990     True
# 9991     True
# 9992     True
# 9993    False
# Length: 9994, dtype: bool

# %%
df.drop_duplicates()
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# # VISUALIZING THE DATASET :

# %% [markdown]
# # 1) Region vs Sales and Profit

# %%
df["Region"].value_counts().plot.pie(autopct="%2f")
plt.show()

# %%
#Total Sum of the Sales from all the different Regions.
df.groupby(["Region"]).agg({"Sales":"sum"}).sort_values(by='Sales',ascending=False)
# Out:
#                Sales
# Region
# West     725457.8245
# East     678781.2400
# Central  501239.8908
# South    391721.9050

# %%
#Highest Sales are from West region.
df.groupby(["Region"]).agg({"Sales":"sum"}).sort_values(by='Sales',ascending=False).plot(kind='barh',legend=True,color='Red')
# Out:
# <AxesSubplot:ylabel='Region'>

# %%
#Highest Sales and Profit is from West region.
#Lowest Sales are from South Region and lowest profit is from Central Region.

df.groupby('Region')[['Profit','Sales']].sum().sort_values(by='Profit',ascending=False).plot.bar(color=['blue','red'])
# Out:
# <AxesSubplot:xlabel='Region'>

# %% [markdown]
# # 2) Country vs Sales and Profit

# %%
#Sales are only from country United States.
df["Country"].value_counts()
# Out:
# United States    9994
# Name: Country, dtype: int64

# %%
#Total Sales: 2.2 Million
#Total Profit: 2 Lakhs 86 Thousand
df.groupby("Country").agg({"Sales":"sum","Profit":"sum"})
# Out:
#                       Sales       Profit
# Country
# United States  2.297201e+06  286397.0217

# %% [markdown]
# # 3) State vs Sales and Profit

# %%
df.State.value_counts()
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %%
#Highest Sales are from California and then New York.
#Least Sales are from North Dakota.

x=df.groupby(["State"]).agg({"Sales":"sum"}).sort_values(by='Sales',ascending=False)
x.plot.bar(legend=True,color='green',figsize=(10,10))
# Out:
# <AxesSubplot:xlabel='State'>

# %%
#Highest Profit is from California and then New York.
#Highest Loss is from Texas.
y=df.groupby(["State"]).agg({"Profit":"sum"}).sort_values(by='Profit',ascending=False)
y.plot.bar(legend=True,color='purple',figsize=(10,10))
# Out:
# <AxesSubplot:xlabel='State'>

# %% [markdown]
# # 4) Category vs Sales and Profit

# %%
#All the Category of products are contributing almost equally in terms of Sales but Highest is of Technology.
#Highest Profit is also from Technology category and lowest profit is from category Furniture.

df.groupby(["Category"]).agg({"Sales":"sum","Profit":"sum"}).sort_values(by='Sales',ascending=False)
# Out:
#                        Sales       Profit
# Category
# Technology       836154.0330  145454.9481
# Furniture        741999.7953   18451.2728
# Office Supplies  719047.0320  122490.8008

# %%
df.groupby('Category')[['Sales','Profit']].sum().sort_values(by='Sales',ascending=False).plot.bar(color=['pink','purple'],legend=True)
# Out:
# <AxesSubplot:xlabel='Category'>

# %% [markdown]
# # 5) Sub-Category vs Sales and Profit

# %%
#Arranging by Highest Sales to Lowest.
df.groupby(["Sub-Category"]).agg({"Sales":"sum","Profit":"sum"}).sort_values(by='Sales',ascending=False)
# Out:
#                     Sales      Profit
# Sub-Category
# Phones        330007.0540  44515.7306
# Chairs        328449.1030  26590.1663
# Storage       223843.6080  21278.8264
# Tables        206965.5320 -17725.4811
# Binders       203412.7330  30221.7633
# Machines      189238.6310   3384.7569
# Accessories   167380.3180  41936.6357
# Copiers       149528.0300  55617.8249
# Bookcases     114879.9963  -3472.5560
# Appliances    107532.1610  18138.0054
# Furnishings    91705.1640  13059.1436
# Paper          78479.2060  34053.5693
# Supplies       46673.5380  -1189.0995
# Art            27118.7920   6527.7870
# Envelopes      16476.4020   6964.1767
# Labels         12486.3120   5546.2540
# Fasteners       3024.2800    949.5182

# %%
#Arranging by Highest Profit to Lowest Profit.
df.groupby(["Sub-Category"]).agg({"Sales":"sum","Profit":"sum"}).sort_values(by='Profit',ascending=False)
# Out:
#                     Sales      Profit
# Sub-Category
# Copiers       149528.0300  55617.8249
# Phones        330007.0540  44515.7306
# Accessories   167380.3180  41936.6357
# Paper          78479.2060  34053.5693
# Binders       203412.7330  30221.7633
# Chairs        328449.1030  26590.1663
# Storage       223843.6080  21278.8264
# Appliances    107532.1610  18138.0054
# Furnishings    91705.1640  13059.1436
# Envelopes      16476.4020   6964.1767
# Art            27118.7920   6527.7870
# Labels         12486.3120   5546.2540
# Machines      189238.6310   3384.7569
# Fasteners       3024.2800    949.5182
# Supplies       46673.5380  -1189.0995
# Bookcases     114879.9963  -3472.5560
# Tables        206965.5320 -17725.4811

# %%
df["Sub-Category"].value_counts().plot.pie(autopct='%2f',figsize=(8,10))
# Out:
# <AxesSubplot:ylabel='Sub-Category'>

# %%
#Highest Profit: Copiers,Phones,Accessories,Paper.
#Loss:Tables,Bookcases,Supplies.
df.groupby(["Sub-Category"]).agg({"Profit":"sum"}).sort_values(by='Profit',ascending=False).plot.bar(legend=True,color='red',figsize=(10,8))
# Out:
# <AxesSubplot:xlabel='Sub-Category'>

# %%
#Here we can compare the difference between Sales and Profit w.r.t Sub Category
#Sales of Tables are high but no gains only loss.
#Chairs Sales are high but profit compared is low.
df.groupby(["Sub-Category"]).agg({"Profit":"sum","Sales":"sum"}).sort_values(by='Sales',ascending=False).plot.bar(legend=True,color=['red','black'],figsize=(10,10))
# Out:
# <AxesSubplot:xlabel='Sub-Category'>

# %% [markdown]
# # 6)Segment vs Sales and Profit

# %%
df.Segment.value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
df.groupby('Segment')[['Sales','Profit']].sum().sort_values(by='Sales',ascending=False).plot.bar(color=['pink','purple'],figsize=(10,10))
# Out:
# <AxesSubplot:xlabel='Segment'>

# %% [markdown]
# # 7) Shipment vs Sales and Profit

# %%
df["Ship Mode"].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
#Highest Sales and Profit are through Standard Class Shipment Mode.
#lowest Sales and Profit is through Same Day Shipment Mode.
df.groupby('Ship Mode')[['Sales','Profit']].sum().sort_values(by='Sales',ascending=False).plot.bar(figsize=(10,10))
# Out:
# <AxesSubplot:xlabel='Ship Mode'>

# %% [markdown]
# # 8) Discount vs Profit

# %%
plt.figure(figsize=(10,10))
sns.lineplot(x='Discount',y='Profit',data=df,color='maroon')
# Out:
# <AxesSubplot:xlabel='Discount', ylabel='Profit'>

# %% [markdown]
# # 9) Sales vs Profit

# %%
plt.figure(figsize=(10,10))
sns.lineplot(x='Sales',y='Profit',data=df)
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='Profit'>

# %% [markdown]
# # 10) Quantity vs Discount

# %%
plt.figure(figsize=(8,10))
sns.lineplot(x='Quantity',y='Discount',color='green',data=df)
# Out:
# <AxesSubplot:xlabel='Quantity', ylabel='Discount'>

# %% [markdown]
# # 11) Quantity vs Sales

# %%
plt.figure(figsize=(8,10))
sns.lineplot(x='Quantity',y='Sales',color='green',data=df)
# Out:
# <AxesSubplot:xlabel='Quantity', ylabel='Sales'>

# %% [markdown]
# # 12) Discount vs Category and Sub-Category

# %%
#Highest discount is given on  products of category Office Supplies and lowest on category Technology
plt.figure(figsize=(8,8))
df.groupby('Category')[['Discount']].count().plot.bar(legend=True)
# Out:
# <AxesSubplot:xlabel='Category'>

# %%
#Sub-Category vs Discount
plt.figure(figsize=(10,10))
df.groupby('Sub-Category')[['Discount']].count().plot.bar(legend=True)
# Out:
# <AxesSubplot:xlabel='Sub-Category'>

# %% [markdown]
# #

# %% [markdown]
# # OBSERVATIONS:

# %% [markdown]
# # 1)All the sales are from Country United States.
# # 2)Total Sales: 2.2 Million
# # 3)Total Profit: 2 Lakhs 86 Thousand
# # 4)Highest Sales are from:
# ###  A) Region: WEST
# ###   B) States(Top 10):
#          California
#          New York
#          Texas
#          Washington
#          Pennsylvania
#          Florida
#          Illinois
#          Ohio
#          Michigan
#          Virginia
# ###   C) Category: Technology
#
# ###   D) Sub Category(Top 8):
#          Phones
#          Chairs
#          Storage
#          Chairs
#          Tables
#          Machines
#          Accessories
#          Bookcases
# ###   E) Shipment Mode: Standard Class
# ###   F) Segment : Consumer
#
# # 5)Least Sales:
# ### A) Region:SOUTH
# ### B)States:
#       North Dakota
#       West Virginia
#       Maine
#       South Dakota
#       Wyoming
#       District of Columbia
#       Kansas
#       Idaho
#       lowa
#       New Mexico
# ### C) Category: Office Supplies
# ### D) Sub-Category:
#        Fasteners
#        Labels
#        Envelopes
# ### E) Shipment Mode: Same Day
# ### F)Segment: Home Office
#
# # 6) Profit:
# ### A)Region: WEST
# ### B)States(Top 10):
#       California
#       New York
#       Washington
#       Michigan
#       Virginia
#       Indiana
#       Georgia
#       Kentucky
#       Minnesota
#       Delaware
# ### C) Category: Technology
# ### D) Sub-Category(Top 5):
#         Copiers
#         Phones
#         Accessories
#         Paper
#         Binders
#         Chairs
# ### E) Ship Mode: Standard Class
# ### F)Segment: Consumer
#
# # 7) Loss:
# ### A)Region: CENTRAL
# ### B)States:
#      Texas
#      Ohio
#      Pennsylvania
#      Illinois
#      North Carolina
#      Colorado
#      Tennessee
#      Arizona
#      Florida
#      Oregon
#
# ### C) Category: Furniture
# ### D) Sub-Category:
#      Tables
#      Bookcases
#      Supplies
# ### E) Ship Mode: Same Day
# ### F)Segment: Home Office
#
# # 8) Discounts ranging from 0 to 20 percent appear to be the most effective in            driving sales.
# # 9) Discount on Category Office Supplies is high but sales of products under          this category is low.
# # 10) Sales of product quantity of about 13 is high.
# # 11) Highest discount is given on  products of category Office Supplies and                lowest on category Technology.

# %% [markdown]
# #

# %% [markdown]
# # SUGGESTIONS TO IMPROVE SALES:
# ### 1) Analyse the region where the company's products are underrepresented. Consider expanding your reach              through targeted marketing campaigns or opening new store locations in these areas.
# ### For e.g. Marketing should be improved in South Region and all the states where least sales take place.
#
# ### 2) Technology and Office Supplies categories stand out for their high profitability, while the Furniture category          lags behind in terms of profitability.  Discount on Category Office Supplies is high but sales of products                     under this category is low. Discount on Category Furniture should be quite increased as they have better                 sales than office supplies.
# ### 3) Focus on Products which are top-performers in terms of sales and profitability. Focus on promoting and              expanding the offerings of these successful products while reevaluating or optimizing the less performing                ones.
# ### 4) Evaluate the pricing strategy for different products and categories. Assess if any products are priced too              high or too low compared to their competitors or market demand. Adjusting prices accordingly can impact                sales positively. For e.g. Among sub-categories, Phones exhibit high sales, while Chairs demonstrate high                sales but lower profitability compared to  Phones. Similarly tables sales are high but resulting into only loss.            Machines have high sales but very low profit.
# ### 5) Giving Discount about 20% should be avoided as it is resulting into loss. We can notice that about 50% is            resulting into highest loss. Discounts ranging from 0 to 20 percent appear to be the most effective in driving              sales.
# ### 6)Seek customer feedback: Engage with customers who have purchased the loss-making products to gather            feedback and understand their perspectives. Their insights can provide valuable information on how to                     mprove the products or make necessary adjustments.
